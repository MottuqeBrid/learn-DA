# %% [markdown]
# ### CHAPTER 7
# # Data Cleaning and Preparation

# %%
import pandas as pd
import numpy as np

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])
float_data
# Out:
# 0    1.2
# 1   -3.5
# 2    NaN
# 3    0.0
# dtype: float64

# %%
float_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
string_data = pd.Series(["aardvark", np.nan, None, "avocado"])
string_data
# Out:
# 0    aardvark
# 1         NaN
# 2        None
# 3     avocado
# dtype: object

# %%
string_data.isnull()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
float_data = pd.Series([1, 2, None], dtype='float64')
float_data
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
float_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notna()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],
                     [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna()  # Drops any row with NaN values
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(how='all')  # Drops any row with all NaN values
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4] = np.nan
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
data.dropna(axis="columns", how='all')  # Drops any column with all NaN values
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
df = pd.DataFrame(np.random.standard_normal((7, 3)))
df
# Out:
#           0         1         2
# 0 -0.016797 -0.517389  0.615454
# 1  0.897770  0.664381 -1.004279
# 2 -0.808611  0.013866  0.059678
# 3  1.420469  0.605489  0.417605
# 4 -0.302169  0.011447 -2.319039
# 5  1.535266 -0.243608 -0.140582
# 6  0.372790  0.835380  0.218853

# %%
df.iloc[:4, 1] = np.nan
df.iloc[:2, 2] = np.nan
df
# Out:
#           0         1         2
# 0 -0.016797       NaN       NaN
# 1  0.897770       NaN       NaN
# 2 -0.808611       NaN  0.059678
# 3  1.420469       NaN  0.417605
# 4 -0.302169  0.011447 -2.319039
# 5  1.535266 -0.243608 -0.140582
# 6  0.372790  0.835380  0.218853

# %%
df.dropna()
# Out:
#           0         1         2
# 4 -0.302169  0.011447 -2.319039
# 5  1.535266 -0.243608 -0.140582
# 6  0.372790  0.835380  0.218853

# %%
df.dropna(thresh=2)  # Keep only rows with at least 2 non-NaN values
# Out:
#           0         1         2
# 2 -0.808611       NaN  0.059678
# 3  1.420469       NaN  0.417605
# 4 -0.302169  0.011447 -2.319039
# 5  1.535266 -0.243608 -0.140582
# 6  0.372790  0.835380  0.218853

# %% [markdown]
# ### Filling In Missing Data

# %%
df.fillna(0)  # Fill NaN values with 0
# Out:
#           0         1         2
# 0 -0.016797  0.000000  0.000000
# 1  0.897770  0.000000  0.000000
# 2 -0.808611  0.000000  0.059678
# 3  1.420469  0.000000  0.417605
# 4 -0.302169  0.011447 -2.319039
# 5  1.535266 -0.243608 -0.140582
# 6  0.372790  0.835380  0.218853

# %%
df.fillna({1:0.5, 2:0})  # Fill NaN values in column 1 with 0.5 and column 2 with 0
# Out:
#           0         1         2
# 0 -0.016797  0.500000  0.000000
# 1  0.897770  0.500000  0.000000
# 2 -0.808611  0.500000  0.059678
# 3  1.420469  0.500000  0.417605
# 4 -0.302169  0.011447 -2.319039
# 5  1.535266 -0.243608 -0.140582
# 6  0.372790  0.835380  0.218853

# %%
df = pd.DataFrame(np.random.standard_normal((6, 3)))
df.iloc[2:, 1] = np.nan
df.iloc[4:, 2] = np.nan
df
# Out:
#           0         1         2
# 0 -0.506779 -0.771091  0.746665
# 1 -1.332065  0.033029  0.495725
# 2 -1.608497       NaN  0.608341
# 3 -0.850720       NaN -0.452997
# 4 -0.488704       NaN       NaN
# 5  0.425391       NaN       NaN

# %%
df.fillna(method='ffill')  # Forward fill NaN values
# Out:
# C:\Users\sahor\AppData\Local\Temp\ipykernel_3528\2883871002.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')  # Forward fill NaN values
#           0         1         2
# 0 -0.506779 -0.771091  0.746665
# 1 -1.332065  0.033029  0.495725
# 2 -1.608497  0.033029  0.608341
# 3 -0.850720  0.033029 -0.452997
# 4 -0.488704  0.033029 -0.452997
# 5  0.425391  0.033029 -0.452997

# %%
df.fillna(method='ffill', limit=2)  # Forward fill NaN values with a limit of 2
# Out:
# C:\Users\sahor\AppData\Local\Temp\ipykernel_3528\3537515366.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', limit=2)  # Forward fill NaN values with a limit of 2
#           0         1         2
# 0 -0.506779 -0.771091  0.746665
# 1 -1.332065  0.033029  0.495725
# 2 -1.608497  0.033029  0.608341
# 3 -0.850720  0.033029 -0.452997
# 4 -0.488704       NaN -0.452997
# 5  0.425391       NaN -0.452997

# %%
data = pd.Series([1., np.nan, 3.5, np.nan, 7])
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.fillna(data.mean())  # Fill NaN values with the mean of the Series
# Out:
# 0    1.000000
# 1    3.833333
# 2    3.500000
# 3    3.833333
# 4    7.000000
# dtype: float64

# %% [markdown]
# ## 7.2 Data Transformation

# %% [markdown]
# ### Removing Duplicates

# %%
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"],
                     "k2": [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()  # Check for duplicate rows
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()  # Drop duplicate rows
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data["v1"] = range(7)
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(subset=["k1"])  # Drop duplicates based on column 'k1'
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
data.drop_duplicates(["k1", "k2"], keep="last")  # Drop duplicates based on columns 'k1' and 'k2'
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6
